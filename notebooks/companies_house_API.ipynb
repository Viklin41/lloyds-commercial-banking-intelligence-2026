# %% [markdown]
# To start using the notebook:
# 1. Install dependencies in your .venv:
#
# ```
# pip install -r requirements.txt
# ```
#
# 2. Create a file named ```.env``` and add your Companies House API key as ```CH_API_KEY=your_actual_api_key_here```

# %%
import os
from dotenv import load_dotenv

load_dotenv()

CH_API_KEY = os.getenv("CH_API_KEY")

if not CH_API_KEY:
    raise ValueError("CH_API_KEY not found. Check your .env file.")
