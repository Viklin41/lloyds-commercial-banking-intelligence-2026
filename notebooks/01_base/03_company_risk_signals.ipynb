# %% [markdown]
# ### 1. Importing and cleaning the dataset

# %%
import pandas as pd
from pathlib import Path
import warnings

warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)

TODAY = pd.Timestamp("2026-06-11") # pinned for reproducibility

INPUT_PATH  = "../data/processed/filtered_bb_sme_sectors.csv"
OUTPUT_PATH = "../data/processed/company_profiles_scored.csv"
FIGURES_DIR = Path("../figures")
FIGURES_DIR.mkdir(exist_ok=True)

# %%
df = pd.read_csv(INPUT_PATH, low_memory=False)
df.columns = df.columns.str.strip()

DATE_COLS = [
    "IncorporationDate",
    "Accounts.NextDueDate",
    "Accounts.LastMadeUpDate",
    "ConfStmtNextDueDate",
    "ConfStmtLastMadeUpDate",
] + [f"PreviousName_{i}.CONDATE" for i in range(1, 11)]

for col in DATE_COLS:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], dayfirst=True, errors="coerce")

print(f"Loaded {len(df):,} rows, {df.shape[1]} columns")
df[["CompanyName", "sector", "segment", "Accounts.AccountCategory"]].head(3)
# Out:
# Loaded 1,372,321 rows, 57 columns
#                     CompanyName                            sector     segment  \
# 0              !ABRIDGE TAX LTD            Fast growth & emerging  No Filings
# 1  !BIG IMPACT GRAPHICS LIMITED  Technology, legal & professional     Dormant
# 2   !NFLECTION ADVISORY LIMITED  Technology, legal & professional       Small
#
#   Accounts.AccountCategory
# 0        NO ACCOUNTS FILED
# 1                  DORMANT
# 2     TOTAL EXEMPTION FULL

# %%
df.dtypes
# Out:
# CompanyName                                      str
# CompanyNumber                                    str
# RegAddress.CareOf                                str
# RegAddress.POBox                                 str
# RegAddress.AddressLine1                          str
# RegAddress.AddressLine2                          str
# RegAddress.PostTown                              str
# RegAddress.County                                str
# RegAddress.Country                               str
# RegAddress.PostCode                              str
# CompanyCategory                                  str
# CompanyStatus                                    str
# CountryOfOrigin                                  str
# DissolutionDate                              float64
# IncorporationDate                     datetime64[us]
# Accounts.AccountRefDay                       float64
# Accounts.AccountRefMonth                     float64
# Accounts.NextDueDate                  datetime64[us]
# Accounts.LastMadeUpDate               datetime64[us]
# Accounts.AccountCategory                         str
# Returns.NextDueDate                              str
# Returns.LastMadeUpDate                           str
# Mortgages.NumMortCharges                       int64
# Mortgages.NumMortOutstanding                   int64
# Mortgages.NumMortPartSatisfied                 int64
# Mortgages.NumMortSatisfied                     int64
# SICCode.SicText_1                                str
# SICCode.SicText_2                                str
# SICCode.SicText_3                                str
# SICCode.SicText_4                                str
# LimitedPartnerships.NumGenPartners             int64
# LimitedPartnerships.NumLimPartners             int64
# URI                                              str
# PreviousName_1.CONDATE                datetime64[us]
# PreviousName_1.CompanyName                       str
# PreviousName_2.CONDATE                datetime64[us]
# PreviousName_2.CompanyName                       str
# PreviousName_3.CONDATE                datetime64[us]
# PreviousName_3.CompanyName                       str
# PreviousName_4.CONDATE                datetime64[us]
# PreviousName_4.CompanyName                       str
# PreviousName_5.CONDATE                datetime64[us]
# PreviousName_5.CompanyName                       str
# PreviousName_6.CONDATE                datetime64[us]
# PreviousName_6.CompanyName                       str
# PreviousName_7.CONDATE                datetime64[us]
# PreviousName_7.CompanyName                       str
# PreviousName_8.CONDATE                datetime64[us]
# PreviousName_8.CompanyName                       str
# PreviousName_9.CONDATE                datetime64[us]
# PreviousName_9.CompanyName                       str
# PreviousName_10.CONDATE               datetime64[us]
# PreviousName_10.CompanyName                      str
# ConfStmtNextDueDate                   datetime64[us]
# ConfStmtLastMadeUpDate                datetime64[us]
# sector                                           str
# segment                                          str
# dtype: object

# %%
df['RegAddress.CareOf'].value_counts()
# Out:
# RegAddress.CareOf
# HILLIER HOPKINS LLP          72
# TAXASSIST ACCOUNTANTS        55
# C/O                          37
# FEB CHARTERED ACCOUNTANTS    36
# PETS AT HOME LIMITED         34
#                              ..
# MARK LODGE                    1
# ZINIR LTD                     1
# MR M NIA                      1
# ZRG LTD                       1
# C/O GERLINDE GNIEWOSZ         1
# Name: count, Length: 4230, dtype: int64

# %% [markdown]
# ### 2. Financial Health Metrics

# %% [markdown]
# For now I will limit myself to static metrics derived from the compliance and mortgage register columns. Later on we could link up to the Companies house API and retrieve P&L balance sheets for a more detailed breakdown.
#
# I create the following metrics:
# 1. Compamny age in years
# 2. Debt ratio: Measure the share of mortage charges still outstanding; equal to zero for companies with no charge history.
# 3.

# %%
# M1: Company age in years
df["company_age_years"] = (TODAY - df["IncorporationDate"]).dt.days / 365.25

print("company_age_years:")
print(df["company_age_years"].describe().round(2))
# Out:
# company_age_years:
# count    1372321.00
# mean           9.48
# std           11.08
# min            0.03
# 25%            1.99
# 50%            6.14
# 75%           13.13
# max          169.70
# Name: company_age_years, dtype: float64

# %%
# M2: Debt ratio
df["debt_ratio"] = (
    df["Mortgages.NumMortOutstanding"]
    / df["Mortgages.NumMortCharges"].clip(lower=1)
)
df.loc[df["Mortgages.NumMortCharges"] == 0, "debt_ratio"] = 0.0

print("debt_ratio (0 = all clear or no history, 1 = all charges still outstanding):")
print(df["debt_ratio"].describe().round(3))
print(f"\nCompanies with >=1 charge: {(df['Mortgages.NumMortCharges'] >= 1).sum():,}")
print(f"Mean debt_ratio for those: {df.loc[df['Mortgages.NumMortCharges'] >= 1, 'debt_ratio'].mean():.3f}")
# Out:
# debt_ratio (0 = all clear or no history, 1 = all charges still outstanding):
# count    1372321.000
# mean           0.052
# std            0.208
# min            0.000
# 25%            0.000
# 50%            0.000
# 75%            0.000
# max            1.000
# Name: debt_ratio, dtype: float64
#
# Companies with >=1 charge: 128,637
# Mean debt_ratio for those: 0.550
